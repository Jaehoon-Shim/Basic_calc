# %%
import torch
import torch.nn as nn

layer = nn.Linear(2, 3)

print(layer.weight)
print(layer.weight.shape)
print(layer.weight.T.shape)
# Out:
# Parameter containing:
# tensor([[ 0.2198,  0.6217],
#         [-0.4798, -0.1252],
#         [ 0.6802, -0.1503]], requires_grad=True)
# torch.Size([3, 2])
# torch.Size([2, 3])
