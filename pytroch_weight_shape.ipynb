# %%
import torch
import torch.nn as nn

layer = nn.Linear(2, 3)

print(layer.weight)
print(layer.weight.shape)
print(layer.weight.T.shape)
# Out:
# Parameter containing:
# tensor([[-0.6963,  0.0927],
#         [ 0.2686,  0.1419],
#         [ 0.0532, -0.3215]], requires_grad=True)
# torch.Size([3, 2])
# torch.Size([2, 3])
